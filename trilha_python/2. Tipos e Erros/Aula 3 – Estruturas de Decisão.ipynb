# %%
distancia_do_gol = 20

if distancia_do_gol < 18:
    print("A distância do gol é:")

# %%
forca_do_chute = 87
reflexo_goleiro = 60

if forca_do_chute > reflexo_goleiro:
    print("Gol!")
else:
    print("Defesa do goleiro!")

# %%
gravidade_falta = 'leve'

if gravidade_falta == 'leve':
    print("O jogador recebeu adivertencia.")
elif gravidade_falta == 'moderada':
    print("O jogador recebeu cartão amarelo.")
else:
    print("O jogador recebeu cartão vermelho.")

# %%
saldo = 1

if saldo >= 10:
    print("Saldo positivo.")
elif saldo == 2:
    print("Saldo neutro.")
elif saldo = 0:
    print("Saldo neutro.")
else:
    print("Saldo negativo.")

# %% [markdown]
# ### Exercício 1 – Descobrindo os tipos ###
#
#
# Observe os valores abaixo:
#
# nome = "Brasil"
#
# gols = 3
#
# posse_bola = 58.7
#
# classificado = True
#
# Crie um programa que mostre o tipo de cada uma dessas variáveis utilizando type().
# Ao executar, o programa deve permitir identificar quais valores são str, int, float e bool.

# %%
nome = "Brasil"
gols = 3
posse_bola = 58.7
classificado = True

print(f"A Variavel nome é do tipo, {type(nome)} e contem a informação: {nome}")
print(f"A Variavel nome é do tipo, {type(gols)} e contem a informação: {gols}")
print(f"A Variavel nome é do tipo, {type(posse_bola)} e contem a informação: {posse_bola}")
print(f"A Variavel nome é do tipo, {type(classificado)} e contem a informação: {classificado}")

# %% [markdown]
# ### Exercício 2 – Verificando os tipos ###
#
#
# Considere as variáveis:
#
# numero_camisa = 10
#
# jogador = "Raphinha"
#
# Utilize isinstance() para verificar:
#
# se numero_camisa é um int;
# se numero_camisa é uma str;
# se jogador é uma str.
#
# Mostre o resultado de cada verificação na tela.

# %%
numero_camisa = 10
jogador = "Raphina"

if isinstance( numero_camisa, int):
    print(f'A variavel numero camisa é um tipo inteiro coma informação: {numero_camisa}')
else:
    print(f'A variavel numero_camisa não é do tipo inteiro ela é: {type(numero_camisa)}, com a informação de: {numero_camisa}')
if isinstance( jogador, str):
    print(f'A variave jogador é um tipo texto e é: {jogador}')
else:
    print(f'A variavel jogador não é do tipo int ela é: {type(jogador)}, com a informação de: {jogador}')

# %% [markdown]
# ### Exercício 3 – Encontre o Erro e Corrija ###
#
# O código abaixo apresenta um erro:
#
# gols = "2"
# novo_gol = gols + 1
#
# print(novo_gol)
#
# Execute o código, observe a mensagem apresentada pelo Python e responda:
# Qual erro ocorreu?
# Quais são os tipos dos valores envolvidos?
# Por que esses valores não podem ser utilizados dessa forma?
# Corrija o programa para que o resultado exibido seja 3.

# %%
gols = "2"

if isinstance(gols, str):
    gols = int(input(f"Gols não é do tipo inteiro, digite um numero"))
    golsa_att = gols + 1
    print(f'A soma dos gols é: {golsa_att}')
else:
    golsa_att = gols + 1
    print(f'A soma de gols é de {gols}')

# %% [markdown]
# ### Exercício 4 – Trabalhando com input() ###
#
#
#
# Crie um programa que pergunte ao usuário quantos gols uma seleção marcou em uma partida.
#
# Depois:
#
#     descubra o tipo do valor recebido diretamente pelo input();
# converta esse valor para int;
#     mostre novamente o tipo depois da conversão;
# calcule quantos gols a seleção teria caso marcasse mais um.
#
# Exemplo de entrada:
#
# Quantos gols a seleção marcou? 2
# Resultado esperado ao final:
# Com mais um gol, a seleção teria 3 gols.

# %%
gols_marcados = input('Quantos gols o Brasil marcou: ')

if isinstance(gols_marcados, str):
    print('Sua informação é do tipo texto:',type(gols_marcados))
    gol = int(gols_marcados)
    print('Sua informação foi convertda para tipo inteiro:',type(gol))
    soma_gol = gol + 1

print(f'Com mais um gol a seleção teria marcado {soma_gol}')

# %% [markdown]
# Exercício 5 – Convertendo valores decimais
#
#
# Crie um programa que peça ao usuário:
#
# o nome de um jogador;
# sua nota na partida.
#
# A nota pode possuir casas decimais, como 8.5.
#
# Converta a nota para o tipo adequado e exiba uma mensagem semelhante a:
#
# Vinicius recebeu a nota 8.5.
#
# Antes de finalizar, utilize type() para verificar se a nota foi realmente convertida para o tipo esperado.

# %%
nome_jogador = input('Qual o nome do Jogado: ')
nota_jogador = float(input('Qual a nota desse jogador na partida: '))

print(f'A nota da partida para o {nome_jogador} foi de {nota_jogador} ')

# %% [markdown]
# Considere:
#
# numero = 10
# jogador = "Rodrygo"
#
# Crie uma mensagem que resulte em:
#
# O jogador Rodrygo veste a camisa 1.
#
# Para este exercício, faça a construção da mensagem utilizando +.
#
# Observe o erro que acontece ao tentar concatenar diretamente numero com os textos e depois utilize str() para corrigir o problema.
#
# Explique por que a conversão foi necessária.

# %%
numero_camisa = 10
jogador = "Raphina"
tipo_numero = type(numero_camisa)
tipo_jogador = type(jogador)

if isinstance( numero_camisa, int):
    numero_camisa_att = str(numero_camisa)
    print(f'O jogadr {jogador} veste a camisa ' + numero_camisa_att + '.')
    print(f'A variavel numero camisa era do tipo {tipo_numero}, e o nome do jogador era do tipo {tipo_jogador} então não é possivel concatenar 2 tipos de informações.')

# %% [markdown]
# Exercício 7 – Deixando os valores explícitos
#
# Crie as seguintes variáveis utilizando Type Hint:
#
# nome da seleção → texto;
# quantidade de vitórias → número inteiro;
# aproveitamento → número decimal;
# seleção classificada → valor booleano.
#
# Atribua um valor para cada variável.
#
# Depois, altere propositalmente uma delas para um valor de outro tipo e observe o comportamento do Python.
#
# Com base no que aconteceu, responda:
#
# O Type Hint impede que uma variável receba outro tipo de valor durante a execução?

# %%
nome_selecao: str = input('Qual o nome da selecão:')
quantidade_vitorias: int = input('Quantas vitorias ela teve na copa do mundo')
aproveitamento: float = 19/quantidade_vitorias
selecao_classificada: bool = bool(input('Selecão classificada?'))

print(f'O nome da seleção é: {nome_selecao}')
print(f'Venceu {quantidade_vitorias}')
print(f'aproveitamento foi de {aproveitamento}')
print( f'Selecão classificada {selecao_classificada}')

# Sim o codigo cobreu pois o tipo adicionado no Type Hint espera receber a tipagem escolhida unsupported operand type(s) for /: 'int' and 'str'

# %% [markdown]
# Exercício 8 – Impedindo o programa de quebrar
#
#
# Crie um programa que pergunte a idade do usuário:
#
# Converta a resposta para int.
#
# Use try/except para impedir que o programa seja encerrado caso alguém digite algo como: vinte
#
# Se a conversão funcionar, mostre:
# Idade registrada com sucesso.
# Se ocorrer um ValueError, mostre:
# Digite a idade utilizando apenas números.

# %%
while True:
    try:
        idade = int(input('Qual a sua idade?: '))
        print(f'Idade registrada com sucesso: {idade}')
        break
    except ValueError:
        # idade = int(input('Erro na sua informação, digite apenas Numeros: '))
        print(f'Erro na sua informação, digite apenas Numeros')
# Out:
# Erro na sua informação, digite apenas Numeros
# Idade registrada com sucesso: 10

# %% [markdown]
# Exercício 9 – Tratando entrada e validando o valor
#
# Uma avaliação de jogador deve receber uma nota entre 0 e 10.
#
# Crie um programa que peça essa nota ao usuário.
#
# O programa deve:
#
#
# tentar converter a entrada para float;
# tratar um possível ValueError;
# verificar se a nota está entre 0 e 10;
# informar quando a nota estiver fora desse intervalo.
#
# Exemplos:
#
# Digite a nota: oito
# Valor inválido. Digite um número.
#
# Digite a nota: 15
# A nota deve estar entre 0 e 10.
#
# Digite a nota: 8.5
# Nota registrada: 8.5

# %%
while True:

    try:
        nota = float(input(f'Qual a nota do jogador'))
        if nota >= 0 and nota <= 10:
            print(f'Nota registrada com sucesso: {nota}')
            break
        else:
            print(f'Nota inválida, digite um valor entre 0 e 10')
    except ValueError:
        # idade = int(input('Erro na sua informação, digite apenas Numeros: '))
        print(f'Erro na sua informação, digite apenas Numeros')
# Out:
# Erro na sua informação, digite apenas Numeros

# %% [markdown]
# Exercício 10 – Continue perguntando até receber um valor válido
#
# Crie um programa para registrar a quantidade de gols de uma seleção.
#
# O programa deve continuar perguntando:
#
# Quantos gols a seleção marcou?
#
# até que o usuário forneça um número inteiro válido e maior ou igual a zero.
#
# Considere situações como:
#
# Quantos gols a seleção marcou? três
# Entrada inválida.
#
# Quantos gols a seleção marcou? -2
# A quantidade de gols não pode ser negativa.
#
# Quantos gols a seleção marcou? 4
# Quantidade de gols registrada: 4
#
# Para resolver o exercício, utilize os conteúdos estudados até aqui, incluindo:
#
# input();
# conversão com int();
# try/except;
# ValueError;
# condição;
# while.
#
# O programa só deve parar de solicitar a informação quando receber um valor válido.

# %%
while True:

    try:
        gols = int(input(f'Quantos gols a seleção marcou na copa do mundo?'))
        if gols > 0:
            print(f'A seleção marcou: {gols}')
            break
        else:
            print(f'Quantidade de gol inválido, digite um valor numerico positivo')
    except ValueError:
        print(f'Erro na sua informação, digite apenas Numeros')
# Out:
# Quantidade de gol inválido, digite um valor numerico positivo
# Erro na sua informação, digite apenas Numeros
# A seleção marcou: 10
