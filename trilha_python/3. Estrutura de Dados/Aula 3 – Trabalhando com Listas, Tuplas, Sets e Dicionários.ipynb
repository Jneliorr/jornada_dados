# %%
jogadores = [
    "Alisson",
    "Marquinho",
    "Gabriel Magalhões",
    "Thiago Bruno Guimarães",
    "Raphinha",
    "Rodrigo",
    "Vini Jr"
]

# %%
print(jogadores)  # Alisson
print(jogadores[1])  # MArquinho
print(jogadores[-1])  # Gabriel Magalhões
# Out:
# ['Alisson', 'Marquinho', 'Gabriel Magalhões', 'Thiago Bruno Guimarães', 'Raphinha', 'Rodrigo', 'Vini Jr']
# Marquinho
# Vini Jr

# %%
jogadores.append("Eduardo")

# %%
jogadores[3] = "Neymar"

print(jogadores)
# Out:
# ['Alisson', 'Marquinho', 'Gabriel Magalhões', 'Neymar', 'Raphinha', 'Rodrigo', 'Vini Jr', 'Eduardo']

# %%
for indice,jogador in enumerate(jogadores): 
    print(f" - {jogador} | posição :{indice}")
# Out:
#  - Alisson | posição :0
#  - Marquinho | posição :1
#  - Gabriel Magalhões | posição :2
#  - Neymar | posição :3
#  - Raphinha | posição :4
#  - Rodrigo | posição :5
#  - Vini Jr | posição :6
#  - Eduardo | posição :7

# %%
partida = (
    "Brasil",
    "México",
    "Estádio Central",
    "20:00"
)

# %%
vencedores = ["Ana", "Bruno", "Carla"]

# %%
for indice, vencedor in enumerate(vencedores): 
    print(f" {indice+1} Lugar: {vencedor}")
# Out:
#  1 Lugar: Ana
#  2 Lugar: Bruno
#  3 Lugar: Carla

# %%
for indice, vencedor in enumerate(vencedores, start=1):
    print(f"{indice}º Lugar: {vencedor}")
# Out:
# 1º Lugar: Ana
# 2º Lugar: Bruno
# 3º Lugar: Carla
